# %% [markdown]
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {
#     "nbgrader": {
#      "grade": true,
#      "grade_id": "parte_1",
#      "points": 4
#     }
#    },
#    "outputs": [],
#    "source": [
#     "def es_par(n):\n",
#     "    \"\"\"Verifica si un número es par\"\"\"\n",
#     "    return n % 2 == 0\n",
#     "\n",
#     "# Tests (pasan)\n",
#     "assert es_par(2) == True\n",
#     "assert es_par(3) == False"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {
#     "nbgrader": {
#      "grade": true,
#      "grade_id": "parte_2",
#      "points": 6
#     }
#    },
#    "outputs": [],
#    "source": [
#     "def maximo_lista(lista):\n",
#     "    \"\"\"Encuentra el máximo de una lista\"\"\"\n",
#     "    # Este código tiene un error\n",
#     "    max_val = lista[0]\n",
#     "    for num in lista:\n",
#     "        if num > max_val:\n",
#     "            max_val = num\n",
#     "    return max_val\n",
#     "\n",
#     "# Tests (algunos fallarán)\n",
#     "assert maximo_lista([1, 2, 3]) == 3  # Este pasa\n",
#     "assert maximo_lista([-1, -5, -3]) == -1  # Este falla\n",
#     "assert maximo_lista([5]) == 5  # Este pasa"
#    ]
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "Python 3",
#    "language": "python",
#    "name": "python3"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 4
# }
